# %%
from bs4 import BeautifulSoup
import csv
import requests
import pandas as pd

# %%
html = requests.get('https://docs.google.com/spreadsheets/d/1ZcN10BO983D_6sRr3VoSb3ZOn38oV-a1f5EIGSlXrWs/edit#gid=664418087').text
soup = BeautifulSoup(html, "lxml")
tables = soup.find_all("table")
index = 0
for table in tables:
    with open(str(index) + ".csv", "w") as f:
        wr = csv.writer(f, quoting=csv.QUOTE_NONNUMERIC)
        wr.writerows([[td.text for td in row.find_all("td")] for row in table.find_all("tr")])
    index = index + 1
    
dados = pd.read_csv("teste.csv", sep=',')

indexNames = dados[ dados['Status'] == 'out' ].index

# Delete these row indexes from dataFrame
#dados = dados.drop(indexNames , inplace=True)

dados = dados.dropna(axis=0, how='all') 
dados = dados.dropna(axis=1, how='all')
dados = dados.drop(['CPF','E-mail', 'RG', 'Endereço'], axis=1)

dados
# Out:
#       ID                                         Nome         Unnamed: 2  \
# 0   P121  AMÉRICO SEBASTIAN VARELLA PEREIRA DE MORAIS            Américo
# 1   P131                            CLEITON GONÇALVES            Cleiton
# 2   P130                     ALEXANDRE BARÇANTE GOMES          Alexandre
# 3   P118                              DOUGLAS DE SENA               Sena
# 4   P125                    LAUDINEY DA SILVA PEREIRA           Laudiney
# 5   P117                        DOUGLAS MOREIRA GOMES             Itália
# 6   P143                         DANIEL SCHIAVO SODRÉ     Daniel Schiavo
# 7   P102                EVERTON LUIZ AUGUSTO GENEROSO           Generoso
# 8   P124             CHISRI JOSÉ SOARES PEREIRA PAIVA              Kiary
# 9   P139                     MAX MULLER ELER FERREIRA                Max
# 10  P109                     CLAUDIO JUNIO DE ANDRADE            Cláudio
# 11  P104                       THIAGO FERREIRA SIMÕES               Bolt
# 12  P101                          ANDRE SILVA MARQUES              André
# 13  P110                       TIAGO RODRIGUES DUARTE       Thiago Marca
# 14  P113                            JACKSON REIS DIAS            Jackson
# 15  P128                 ADELSON SELIM JOSE DE SALLES            Adelson
# 16  P127                         PAULO HENRIQUE SILVA              Paulo
# 17  P136            RAIDERLONE RICHARD NUNES DE SOUZA                Ray
# 18  P119               LUCAS HENRIQUE JABOUR SALVADOR             Jabour
# 19  P107                        GUILHERME DUARTE COTA               Cota
# 20  P129                    JOAO PAULO MARQUES SAMORA               João
# 21  P103                            ALEF ALVES XAVIER               Alef
# 22  P126             PAULO CESAR MARTINS DA CONCEICAO             Gaspaz
# 23  P145                   LUIZ FELLIPE ALVES RIBEIRO               Luiz
# 24  P132             DOUGLAS DA SILVA COSTA GONÇALVES            Douglas
# 25  P144                            DIOGO SILVA GOMES              Diogo
# 26  P114                DAVISON WILKER DE SOUZA GOMES              Sagat
# 27  P111             LUÍS HENRIQUE RODRIGUES DE ÁVILA      Luís Henrique
# 28  P115                        MIGUEL CHRISTIAN DIAS             Miguel
# 29  P112                CESAR AUGUSTO CORSINO PEREIRA              César
# 30  P108                      GUSTAVO SANTANA ALMEIDA            Gustavo
# 31  P133                       LEONARDO DA SILVA DIAS           Léo Dias
# 32  P137                       VITOR GABRIEL DA SILVA              Vitor
# 33  P106                GILBERTO FRADE MARINHO JUNIOR           Gilberto
# 34  P116                       RAFAEL BARROS BRAGANÇA             Rafael
# 35  P134                 LEONARDO SOUZA GARCIA CABRAL                Léo
# 36  P141                   ARTHUR SOUZA GARCIA CABRAL             Arthur
# 37  P140               GABRIEL MOREIRA DE PAULA SILVA            Gabriel
# 38  P120                 RYAN HENRIQUE SILVA PARREIRA               Ryan
# 39  P105          EDUARDO FILLIPY DE CARVALHO MOREIRA            Eduardo
# 40  P138                     FILIPE VIEIRA DOS SANTOS             Filipe
# 41  P142                     LUIZ FELIPE SARTORI DIAS   Luiz Felipe Dias
# 42  P135                   LUIZ FELLIPE ALVES RIBEIRO  Luiz Felipe Alves
# 43  P122                       DANIEL BARROS BRAGANÇA    Daniel Bragança
# 44  P123                    IVAN LUIZ MONTEIRO JUNIOR               Ivan
#
#    Posição  Número Altura   Peso Data de Nascimento  Status
# 0       WR    85.0   1,84   94,0         02/09/1973     1.0
# 1       DL    97.0   1,83   95,0         25/08/1983     1.0
# 2       OL    52.0   1,78   98,0         25/05/1984     1.0
# 3       DB    50.0   1,74   85,0         26/06/1984     1.0
# 4       OL    71.0   1,78  130,0         13/03/1985     1.0
# 5       DL    55.0   1,83  110,0         08/09/1986     1.0
# 6       LB    25.0   1,73   80,0         19/09/1987     1.0
# 7       OL    74.0   1,88  134,0         20/05/1988     1.0
# 8       LB    26.0   1,73   90,0         30/05/1988     1.0
# 9       QB    88.0   1,81   93,0         26/10/1988     1.0
# 10      DB    10.0   1,70   78,0         23/12/1988     1.0
# 11      WR    81.0   1,90   90,0         14/02/1989     1.0
# 12      WR    87.0   1,92   93,0         05/12/1989     1.0
# 13      DB    29.0   1,75   84,0         24/01/1990     1.0
# 14      OL    72.0   1,90  134,0         03/02/1990     1.0
# 15      LB    51.0   1,70   76,0         07/07/1990     1.0
# 16      OL    70.0   1,80  123,0         25/02/1991     1.0
# 17      DB    15.0   1,83   73,0         23/01/1992     1.0
# 18      DB    28.0   1,90   92,0         27/10/1992     1.0
# 19      WR     8.0   1,73   72,0         26/04/1993     1.0
# 20      DL    91.0   1,80  110,0         11/07/1993     1.0
# 21      WR    13.0   1,76   83,0         02/02/1994     1.0
# 22      WR    14.0   1,89   81,0         09/02/1994     1.0
# 23      WR    18.0   1,83   87,0         19/09/1994     1.0
# 24      RB    32.0   1,69   83,5         24/11/1994     1.0
# 25      DL    54.0   1,80  116,0         29/12/1994     0.0
# 26      WR     1.0   1,86   97,0         23/07/1995     1.0
# 27      DL    99.0   1,86  100,0         12/11/1995     1.0
# 28      DB    22.0   1,86   80,0         24/11/1995     1.0
# 29      QB    12.0   1,84   89,0         16/02/1996     1.0
# 30      QB    11.0   1,76   77,0         11/12/1996     1.0
# 31      WR    84.0   1,88  100,0         23/04/1997     1.0
# 32      DB    30.0   1,75   78,0         05/05/1997     1.0
# 33      RB    31.0   1,75   95,0         07/08/1997     1.0
# 34      OL    79.0   1,85  150,0         28/02/1998     1.0
# 35      LB    59.0   1,73   89,0         03/10/1998     1.0
# 36      DL    36.0   1,80   88,0         07/01/2000     1.0
# 37      DL    96.0   1,75   95,0         13/06/2000     0.0
# 38      RB    21.0   1,67   77,0         11/05/2003     1.0
# 39      DB     3.0   1,78   90,0         17/07/2000     1.0
# 40      DB     NaN    NaN    NaN                NaN     0.0
# 41      DB     NaN    NaN    NaN                NaN     0.0
# 42      DB     NaN    NaN    NaN                NaN     0.0
# 43      OL     NaN    NaN    NaN                NaN     0.0
# 44      RB     NaN    NaN    NaN                NaN     0.0
